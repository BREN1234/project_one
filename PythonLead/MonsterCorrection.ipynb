# %%
from bs4 import BeautifulSoup
import requests,re,pandas as pd
import datetime

import psycopg2
from sqlalchemy import create_engine
from sqlalchemy.sql import text
from notifier import sendErrorMsg
from indeed import getDailyIdFromDailyTable,insertRecordsToRecords

#this function gets portal id from websiteportal 
def getPortalIdFromWebsitePortal(engine):
    with engine.connect() as connection:
        result_set= connection.execute("SELECT id from websiteportal where portal = 'Monster' limit 1;")
        for i in result_set:
            return(i['id'])

# %%
location=[]
company=[]
posted_day=[]
designation=[]
posted_links=[]
summary=[]
companyurl=[]
#dataframe for collecting data job wise
df=pd.DataFrame()
#Main dataframe
dataFrame=pd.DataFrame()

jobList=['Jaspersoft-__2CJaspersoft-Developer','Talend','PowerBI','looker','Couchbase','AngularJS','ReactJS']
countries=['Canada','New York','USA','Ireland','Saudi Arabia','Qatar','Oman','Bahrain','Kuwait']
for country in countries:
    for job in jobList:
        page=1
        numberOfJobs=0
        #repalce %s with page numbers
        #searhUrl="https://www.monster.com/jobs/search/?q=Jaspersoft&where=usa&page=%s"#"https://www.monster.com/jobs/search/?q="+str(job)+"&where="+str(country)+"&tm=0&page=%s"
        searhUrl="https://www.monster.com/jobs/search/?q="+str(job)+"&where="+str(country)+"&tm=0&page=%s"
        response=requests.get((searhUrl)%page) #first page to get number of jobs
        soup=BeautifulSoup(response.text,'lxml')
        #print(soup)
        try:
            numberOfJobs=int(re.findall(r"\d+",soup.find("h2",{"class":"figure"}).text)[0])
            print(numberOfJobs)
            
            #print("number Of jobs"+str(numberOfJobs))
            #manipulating the pages
            if numberOfJobs >200:
                page=10
            elif numberOfJobs >100:
                page=5
            elif numberOfJobs >75:
                page=4
            elif numberOfJobs >50:
                page=3
            elif numberOfJobs >25:
                page=2
            #collecting all the pages
            #print("selected page="+str(page))
            response=requests.get((searhUrl)%page) #first page to get number of jobs
            soup=BeautifulSoup(response.text,'lxml')
            searchResult=soup.find_all("section",class_="card-content ") #getting all the searched Results
            #print("length of the collected page: "+str(len(searchResult)))
            try:
                for i in searchResult:  #iterating one by one 
                    company.append(re.sub("\n","",i.find("div",{"class":"company"}).text))
                    location.append(re.sub("\n|\r","",i.find("div",{"class":"location"}).text))
                    posted_day.append(re.sub("\n","",i.find("time").text))
                    designation.append(re.sub("\n|\r","",i.find("h2").text))
                    posted_links.append(i.find("a",{"data-bypass":"true"})['href'])
            except Exception as e: # for search loop 
                print(e)
            #creating dataframe
            print(len(posted_day),len(posted_links),len(company),len(location),len(designation))
            df['posted_day']=posted_day
            df['posted_date']=datetime.datetime.today().strftime('%Y-%m-%d')
            df['posted_links']=posted_links
            df['company_name']=company
            df['companyurl']=""
            df['location']=[ loc+' '+job for loc in location]
            df['locationurl']=""
            df['designation']=designation
            dataFrame=dataFrame.append(df)
            df=pd.DataFrame()
            location=[]
            company=[]
            posted_day=[]
            designation=[]
            posted_links=[]
            summary=[]
            companyurl=[]
        except Exception as e: #this for number of jobs
            print("There are no Records ",job+" ",e)
print(dataFrame)
"""dataFrame.to_csv("C:/Datasets/JobData/daily_monsters_"+str(datetime.datetime.today().strftime('%Y_%m_%d'))+".csv")
record=[(datetime.datetime.today().date(),'daily_monster_'+str(datetime.datetime.today().strftime('%Y_%m_%d')+".csv"))]
record_df=pd.DataFrame(record,columns=['crawled_date','filename'])
engine = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432/job_data')
daily_id=getDailyIdFromDailyTable(engine,record_df)
portal_id=getPortalIdFromWebsitePortal(engine)
dataMatrix=dataFrame
dataMatrix['day_id']=daily_id
dataMatrix['portal_id']=portal_id
#print(dataMatrix)
print(daily_id,portal_id)
insertRecordsToRecords(engine,dataMatrix)
print(daily_id)
"""
# Out:
# There are no Records  Jaspersoft-__2CJaspersoft-Developer  list index out of range
# There are no Records  Talend  list index out of range
# There are no Records  PowerBI  list index out of range
# There are no Records  looker  list index out of range
# There are no Records  Couchbase  list index out of range
# There are no Records  AngularJS  list index out of range
# There are no Records  ReactJS  list index out of range
# There are no Records  Jaspersoft-__2CJaspersoft-Developer  list index out of range
# There are no Records  Talend  list index out of range
# 1
# 1 1 1 1 1
# There are no Records  looker  list index out of range
# There are no Records  Couchbase  list index out of range
# 16
# 16 16 16 16 16
# 20
# 19 19 19 19 19
# There are no Records  Jaspersoft-__2CJaspersoft-Developer  list index out of range
# 6
# 6 6 6 6 6
# 6
# 6 6 6 6 6
# 1
# 1 1 1 1 1
# 5
# 5 5 5 5 5
# 95
# 91 91 91 91 91
# 84
# 82 82 82 82 82
# There are no Records  Jaspersoft-__2CJaspersoft-Developer  list index out of range
# There are no Records  Talend  list index out of range
# There are no Records  PowerBI  list index out of range
# There are no Records  looker  list index out of range
# There are no Records  Couchbase  list index out of range
# There are no Records  AngularJS  list index out of range
# There are no Records  ReactJS  list index out of range
# There are no Records  Jaspersoft-__2CJaspersoft-Developer  list index out of range
# There are no Records  Talend  list index out of range
# There are no Records  PowerBI  list index out of range
# There are no Records  looker  list index out of range
# There are no Records  Couchbase  list index out of range
# There are no Records  AngularJS  list index out of range
# There are no Records  ReactJS  list index out of range
# There are no Records  Jaspersoft-__2CJaspersoft-Developer  list index out of range
# There are no Records  Talend  list index out of range
# There are no Records  PowerBI  list index out of range
# There are no Records  looker  list index out of range
# There are no Records  Couchbase  list index out of range
# There are no Records  AngularJS  list index out of range
# There are no Records  ReactJS  list index out of range
# There are no Records  Jaspersoft-__2CJaspersoft-Developer  list index out of range
# There are no Records  Talend  list index out of range
# There are no Records  PowerBI  list index out of range
# There are no Records  looker  list index out of range
# There are no Records  Couchbase  list index out of range
# There are no Records  AngularJS  list index out of range
# There are no Records  ReactJS  list index out of range
# There are no Records  Jaspersoft-__2CJaspersoft-Developer  list index out of range
# There are no Records  Talend  list index out of range
# There are no Records  PowerBI  list index out of range
# There are no Records  looker  list index out of range
# There are no Records  Couchbase  list index out of range
# There are no Records  AngularJS  list index out of range
# There are no Records  ReactJS  list index out of range
# There are no Records  Jaspersoft-__2CJaspersoft-Developer  list index out of range
# There are no Records  Talend  list index out of range
# There are no Records  PowerBI  list index out of range
# There are no Records  looker  list index out of range
# There are no Records  Couchbase  list index out of range
# There are no Records  AngularJS  list index out of range
# There are no Records  ReactJS  list index out of range
#       posted_day posted_date  \
# 0   Posted today  2018-08-16
# 0   Posted today  2018-08-16
# 12                  Healthfirst                       New York, NY  AngularJS
# 13                        i-CST                       New York, NY  AngularJS
# 14    Insight Enterprises, Inc.                       New York, NY  AngularJS
# 15              CBS Interactive                       New York, NY  AngularJS
# 0     Open Systems Technologies                    NEW YORK CITY, NY  ReactJS
# 1         American Cybersystems                    New Hyde Park, NY  ReactJS
# 2                   RecruitWise                        Manhattan, NY  ReactJS
# 3                          CBRE                         New York, NY  ReactJS
# 4                          Hays                         New York, NY  ReactJS
# 5     Open Systems Technologies                    NEW YORK CITY, NY  ReactJS
# 6                   RecruitWise                        Manhattan, NY  ReactJS
# 7     Open Systems Technologies                    NEW YORK CITY, NY  ReactJS
# 8     Open Systems Technologies                    NEW YORK CITY, NY  ReactJS
# 9     Open Systems Technologies                    NEW YORK CITY, NY  ReactJS
# 10    Open Systems Technologies                    NEW YORK CITY, NY  ReactJS
# 11    Open Systems Technologies                    NEW YORK CITY, NY  ReactJS
# 12    Open Systems Technologies                    NEW YORK CITY, NY  ReactJS
# ..                          ...        ...                                ...
# 52                     TSYS Inc                       Alpharetta, GA  ReactJS
# 53                         Uber                    San Francisco, CA  ReactJS
# 54                         Amex                         New York, NY  ReactJS
# 55                LanceSoft Inc                        Charlotte, NC  ReactJS
# 56                Citigroup Inc                            Tampa, FL  ReactJS
# 57                         Turo                    San Francisco, CA  ReactJS
# 58                     Curbside                        San Mateo, CA  ReactJS
# 59                     Skiltrek                          Bothell, WA  ReactJS
# 60      Aequor Technologies Inc             Madison, NJ OR Irvine, CA ReactJS
# 61    St. Joseph Medical Center                          Houston, TX  ReactJS
# 62  Axelon Services Corporation                      Pearl River, NY  ReactJS
# 63              CBS Interactive                  Fort Lauderdale, FL  ReactJS
# 64                       Abbott                      Lake Forest, IL  ReactJS
# 65                     TSYS Inc                         Columbus, GA  ReactJS
# 66    Enterprise Solutions Inc.                          Phoenix, AZ  ReactJS
# 67                         Amex                         New York, NY  ReactJS
# 68              CBS Interactive                         New York, NY  ReactJS
# 69    Enterprise Solutions Inc.                        San Diego, CA  ReactJS
# 70                         Amex                          Phoenix, AZ  ReactJS
# 71                     TSYS Inc                         Columbus, GA  ReactJS
# 72    Enterprise Solutions Inc.                          Phoenix, AZ  ReactJS
# 73                         Amex                          Phoenix, AZ  ReactJS
# 74    Enterprise Solutions Inc.                          phoenix, AZ  ReactJS
# 75                         Amex                         New York, NY  ReactJS
# 76    Enterprise Solutions Inc.                          Phoenix, AZ  ReactJS
# 77                         Amex                          Phoenix, AZ  ReactJS
# 78    Enterprise Solutions Inc.                        San Bruno, CA  ReactJS
# 79                         Amex                          Sunrise, FL  ReactJS
# 80                     Atrilogy                           Dallas, TX  ReactJS
# 81                         Amex                         New York, NY  ReactJS
#
#    locationurl                                        designation
# 0                     Software Engineer - .NET, SQL - 100% Remote
# 0                                             AngularJS Developer
# 1                                               Software Engineer
# 2                                               Software Engineer
# 3                                 Senior Python Software Engineer
# 4                                              Front-end Engineer
# 5                                           Sr. Software Engineer
# 6                                        Javascript Web Developer
# 7                                                 DevOps Engineer
# 8                                              Front-End Engineer
# 9                                      Java Developer – Front-End
# 10                                            Front-End Developer
# 11                         JavaScript-HTML-CSS Software Developer
# 12                                           ServiceNow Developer
# 13                                           Full Stack Developer
# 14                                                         Intern
# 15                            Senior Web Developer - CBS News.com
# 0                                      React Developers (4 roles)
# 1                                               Software Engineer
# 2                                    Full-Stack Software Engineer
# 3                                               Software Engineer
# 4                                                 Java / PHP Lead
# 5                                             FullStack Developer
# 6                                        Senior Software Engineer
# 7                                       UI Developer (w- Node.js)
# 8                                        Javascript Web Developer
# 9                                           Frontend Web Engineer
# 10                      Application Integration Software Engineer
# 11                                             Front-End Engineer
# 12                                    Front End Software Engineer
# ..         ...                                                ...
# 52                   Full Stack Engineer, Digital Innovation Team
# 53                     Software Engineer, UI Platform Open Source
# 54                                    VP, Engineering IV: Loyalty
# 55                Senior Full Stack Web Application Developer III
# 56                                             Career Opportunity
# 57                                       Senior Frontend Engineer
# 58                                  Javascript Software Developer
# 59                                       Java Front End Developer
# 60                                        Sitecore Technical Lead
# 61                 Food Service Worker II - (Job Number: 1803355)
# 62                                              Web Developer III
# 63                            Senior UI Engineer - CBS Sports.com
# 64                                          Sr. Software Engineer
# 65                   Full Stack Engineer, Digital Innovation Team
# 66                                                     Automation
# 67              VP, Engineering IV: Application Experience & E...
# 68                            Senior Web Developer - CBS News.com
# 69                                          Software Engineer III
# 70                            Engineer - Mobile & Web Engineering
# 71                   Full Stack Engineer, Digital Innovation Team
# 72                               QA Automation with UFT, Selenium
# 73              Infrastructure Engineer - Converged Infrastruc...
# 74                                 Automation + Selenium Engineer
# 75                      VP, Engineering IV: Demand Gen & Shopping
# 76                                            Automation Selenium
# 77                            American Express Software Developer
# 78                                           Senior Web Developer
# 79                                     Senior Engineer-Full Stack
# 80                            Mobile/Web Development - Dallas, TX
# 81                         Sr. Staff Architect ( Mobile Strategy)
#
# [227 rows x 8 columns]
# 'dataFrame.to_csv("C:/Datasets/JobData/daily_monsters_"+str(datetime.datetime.today().strftime(\'%Y_%m_%d\'))+".csv")\nrecord=[(datetime.datetime.today().date(),\'daily_monster_\'+str(datetime.datetime.today().strftime(\'%Y_%m_%d\')+".csv"))]\nrecord_df=pd.DataFrame(record,columns=[\'crawled_date\',\'filename\'])\nengine = create_engine(\'postgresql+psycopg2://postgres:postgres@localhost:5432/job_data\')\ndaily_id=getDailyIdFromDailyTable(engine,record_df)\nportal_id=getPortalIdFromWebsitePortal(engine)\ndataMatrix=dataFrame\ndataMatrix[\'day_id\']=daily_id\ndataMatrix[\'portal_id\']=portal_id\n#print(dataMatrix)\nprint(daily_id,portal_id)\ninsertRecordsToRecords(engine,dataMatrix)\nprint(daily_id)\n'
